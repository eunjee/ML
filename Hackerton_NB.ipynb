# %%
import pandas as pd
import numpy as np

import os
import re

from eunjeon import Mecab

import time

mecab = Mecab()

# %%
train_data = pd.read_table('ratings_train.txt')

# %%
print('훈련용 리뷰 개수 :',len(train_data))
# document 열에서 중복인 내용이 있다면 중복 제거
train_data['document'].nunique(), train_data['label'].nunique()
train_data.drop_duplicates(subset=['document'], inplace=True)
# Null 값이 존재하는 행 제거
train_data = train_data.dropna(how = 'any')
# 완성형 한글만 데이터로 사용
train_data['document'] = train_data['document'].str.replace("[^가-힣 ]","")
train_data['document'].replace('', np.nan, inplace=True)
train_data = train_data.dropna(how = 'any')

id_data = list(np.array(train_data['id'].tolist()))
x_data = list(np.array(train_data['document'].tolist()))
y_data = list(np.array(train_data['label'].tolist()))

# 최종적으로 정제된 데이터
new_id_data, new_x_data, new_y_data = [], [], []


for i in range(len(id_data)):
    if (x_data[i].strip() != '') and (y_data[i] == 0 or y_data[i] == 1) and (id_data[i] >= 0):
        new_x_data.append(x_data[i])
        new_y_data.append(y_data[i])
        new_id_data.append(id_data[i])


print('new_id_data의 개수:' + str(len(new_id_data)))
print('new_x_data의 개수:' + str(len(new_x_data)))
print('new_y_data의 개수:' + str(len(new_y_data)))
# Out:
# 훈련용 리뷰 개수 : 150000
# new_id_data의 개수:145248
# new_x_data의 개수:145248
# new_y_data의 개수:145248

# %%
TEST_data = pd.read_table('ratings_test.txt')

# %%
print('테스트 리뷰 개수 :',len(TEST_data))

TEST_id_data = list(np.array(TEST_data['id'].tolist()))
raw_TEST_x_data = list(np.array(TEST_data['document'].tolist()))
TEST_y_data = list(np.array(TEST_data['label'].tolist()))

print('id_data의 개수:' + str(len(TEST_id_data)))
print('x_data의 개수:' + str(len(raw_TEST_x_data)))
print('y_data의 개수:' + str(len(TEST_y_data)))
# Out:
# 테스트 리뷰 개수 : 50000
# id_data의 개수:50000
# x_data의 개수:50000
# y_data의 개수:50000

# %% [markdown]
# # Mecab을 이용한 긍부정 사전 만들기

# %%
#긍정 부정 사전 만들기
def split_train(new_x_data,new_y_data):
    p_train, n_train = [],[]
    for i,label in enumerate(new_y_data):
        if label==1:
            p_train.append(new_x_data[i])
        else:
            n_train.append(new_x_data[i])
    return p_train, n_train

# %%
p_train, n_train = split_train(new_x_data,new_y_data)
print(p_train[0])
print(n_train[0])
print(len(p_train))
print(len(n_train))
p_t = " ".join(map(str,p_train))
n_t = " ".join(map(str,n_train))
# Out:
# 흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 아 더빙 진짜 짜증나네요 목소리
# 72293
# 72955

# %%
from eunjeon import Mecab
mecab = Mecab()
p_morphs= mecab.morphs(p_t)
p_vocabulary=list(set(p_morphs))
#p_vocabulary, n_vocabulary = list(set(mecab.morphs(p_train))),list(set(n_train.split(" ")))

# %%
n_morphs = mecab.morphs(n_t)
n_vocabulary=list(set(n_morphs))

# %%
#tf구하기
def get_tf(token, doc):
    tfv = {}
    for tok in token:
        tfv[tok]=doc.count(tok)
    return tfv

# %%
#tf구하기
def get_tf_2(token, vocab):
    tfv = {}
    for i in range(len(vocab)):
        tfv[vocab[i]]=0
    for t in token:
        tfv[t] = tfv[t]+1
    return tfv

# %%
p_tfv = get_tf(p_vocabulary,p_t)
n_tfv = get_tf(n_vocabulary,n_t)

# %%
p_tf = get_tf_2(p_vocabulary,p_morphs)
n_tf = get_tf_2(n_vocabulary,n_morphs)

# %%
import pickle

with open('p_tf_using_p_t.pickle', 'wb') as f:
    pickle.dump(p_tfv, f)
with open ('n_tf_using_n_t.pickle','wb') as f:
    pickle.dump(n_tfv,f)

with open('p_tf_using_p_morphs.pickle', 'wb') as f:
    pickle.dump(p_tfv, f)
with open ('n_tf_using_n_morphs.pickle','wb') as f:
    pickle.dump(n_tf,f)

# %%
#idf구하기 - 긍정 단어장에 있는 단어가 부정에도 있으면 중요도가 떨어진다. 
import math

def get_df(ptfv,ntfv,vocab):
    dfv = dict.fromkeys(vocab,0)
    for d in dfv:
        if d in ptfv:
            dfv[d]+=1
        elif d in ntfv:
            dfv[d]+=1
    return dfv

def get_idf(ptfv,ntfv,vocab):
    idfv = get_df(ptfv,ntfv,vocab)
    for key, val in idfv.items():
        idfv[key] = math.log10(2/(1+float(val)))+1
  
    return idfv

# %%
p_idfv = get_idf(p_tfv,n_tfv,p_vocabulary)
n_idfv = get_idf(p_tfv,n_tfv,n_vocabulary)

# %%
p_tfidf = dict.fromkeys(p_vocabulary,0)
n_tfidf = dict.fromkeys(n_vocabulary,0)

for i,key in enumerate(p_vocabulary):
    p_tfidf[key] = p_tfv[key]*p_idfv[key]

# %%
for i,key in enumerate(n_vocabulary):
    n_tfidf[key] = n_tfv[key]*n_idfv[key]

# %%
import pickle
with open('p_tfidf.pickle', 'wb') as f:
    pickle.dump(p_tfidf, f, pickle.HIGHEST_PROTOCOL)
    
with open('n_tfidf.pickle', 'wb') as f:
    pickle.dump(n_tfidf, f, pickle.HIGHEST_PROTOCOL)

# %%
#상위 500개씩
import operator
p_res = sorted(dict.items(p_tfidf),key=operator.itemgetter(1),reverse=True)
p_res= dict((x,y) for x,y in p_res)
#del p_result['']
print(len(p_res))
# Out:
# 33442

# %%
#부정 단어 500개 추출
n_res = sorted(dict.items(n_tfidf),key=operator.itemgetter(1),reverse=True)

n_res= dict((x,y) for x,y in n_res)
#del n_result['']

# %%
# 두 dictionary의 key만 합쳐서 최종 vocabulary를 만든다. 
p_list = list(p_res.keys())
n_list = list(n_res.keys())
p_list = p_list[0:10000]
n_list = n_list[0:10000]
nb_vocab = list(set(p_list).union(set(n_list)))

# %%
with open('tfidf5000words', 'wb') as f:
    pickle.dump(nb_vocab, f)

# %%
print(nb_vocab[0:100])
print(len(nb_vocab))
# Out:
# ['콧', '실상', '황금', '에로', '다니엘', '했', '지난', '닼', '종', '스필', '마지막', '미달', '분위기', '막판', '풋풋', '더이상', '드려', '예측', '시골', '만들', '기획', '출연진', '강', '쪽', '윽', '셋', '화인', '시청', '더군', '섭', '집중', '진솔', '미니', '역겹', '환장', '시리즈', '어설퍼', '찮다', '크루', '렐', '툰', '반전', '에게서', '언어', '대가리', '로망', '생각난다', '놀랍', '옳', '다만', '언젠', '날라', '메세지', '헝', '불안', '모르', '노튼', '끔', '많', '객관', '반드시', '성적', '작자', '모아', '크리', '그런지', '복', '평생', '국', '니엘', '충격', '태어난', '스포츠', '해준다', '자아', '기영', '러시', '느려', '스란', '잘', '전쟁', '잘생김', '네', '콘서트', '하다', '구역', '으려고', '감동', '생각나', '엽기', '회의', '장국', '졌으면', '아까워서', '여행', '복잡', '밋밋', '소녀', '다시', '영화사']
# 6357

# %% [markdown]
# ## chi-square 이용해 상위 500개의 단어 뽑기

# %%
total_vocab = list(set(p_vocabulary).union(set(n_vocabulary)))

# %%
#ham, ~ham,spam,~spam
h,nh,s,ns = {},{},{},{}

def df(tok,data):
    count = 0
    for i in range(len(data)):
        if tok in data[i]:
            count+=1
    return count


for tok in total_vocab:
    h[tok] = df(tok,p_train)
    nh[tok] = len(p_train)-h[tok]
    s[tok] = df(tok,n_train)
    ns[tok] = len(n_train)-s[tok]

print(h['소재'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-25ab9d7cbfca> in <module>()
#      13     h[tok] = df(tok,p_train)
#      14     nh[tok] = len(p_train)-h[tok]
# ---> 15     s[tok] = df(tok,n_train)
#      16     ns[tok] = len(n_train)-s[tok]
#      17
#
# <ipython-input-79-25ab9d7cbfca> in df(tok, data)
#       5     count = 0
#       6     for i in range(len(data)):
# ----> 7         if tok in data[i]:
#       8             count+=1
#       9     return count
#
# KeyboardInterrupt:

# %%
#chi-sqaure계산
import math
import operator
chi = {}

for t in total_vocab:
    numerator = (h[t]+nh[t]+s[t]+ns[t])* math.pow((h[t]*ns[t]-nh[t]*s[t]),2)
    denominator= (h[t]+s[t])*(h[t]+nh[t])*(s[t]+ns[t])*(nh[t]+ns[t])
    chi[t]=float(numerator/denominator)

chi= sorted(dict.items(chi),key=operator.itemgetter(1),reverse=True)

dict_chi = dict((x,y) for x,y in chi)

# %%
chi_keys = list(dict_chi.keys())

# %%
chi_keys = chi_keys[:500]

# %%
#chikeys dump

with open('chi_keys.pickle', 'wb') as f:
    pickle.dump(chi_keys, f, pickle.HIGHEST_PROTOCOL)

# %%
#top500words 읽어오기
with open('top500word.pkl','rb') as f:
    top500words =pickle.load(f)

# %%
print(len(chi_keys))
# Out:
# 50143

# %% [markdown]
# # feature_x_data만들기

# %%
#tfidf 단어장과 chi square 단어장을 합친다. 
final_vocabulary =nb_vocab+top500words

# %%
from tqdm import tqdm
final_x_data=[]
final_y_data=[]
for i,sentence in enumerate(tqdm(new_x_data)):
    new_sent=''
    for j, word in enumerate(final_vocabulary):
        if word in sentence:
            new_sent += word + ' '
    if new_sent.strip()!='':
        final_x_data.append(new_sent)
        final_y_data.append(new_y_data[i])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 145248/145248 [14:05<00:00, 171.76it/s]

# %%
print(len(final_x_data))
# Out:
# 145211

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
feature_X_train = vectorizer.fit_transform(final_x_data)

# %%
from sklearn.naive_bayes import MultinomialNB # 다항분포 나이브 베이즈 모델

mod = MultinomialNB()
mod.fit(feature_X_train, final_y_data)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# # Test data
# 1. 모든 test 데이터 포함하기
# 2. test데이터도 null인 항목 제거

# %%
#2번
from tqdm import tqdm
final_x_test=[]
final_y_test=[]
for i,sentence in enumerate(tqdm(raw_TEST_x_data)):
    new_sent=''
    for j, word in enumerate(final_vocabulary):
        if word in sentence:
            new_sent += word + ' '
    if new_sent.strip()!='':
        final_x_test.append(new_sent)
        final_y_test.append(TEST_y_data[i])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [04:50<00:00, 172.26it/s]

# %%
feature_X_test = vectorizer.transform(final_x_test)

# %%
# %%time
y_predict=mod.predict(feature_X_test)
# Out:
# Wall time: 16 ms

# %%
from sklearn.metrics import accuracy_score


print('Accuracy: %.2f' % accuracy_score(final_y_test,y_predict))
# Out:
# Accuracy: 0.81

# %%
print("id\tdocument\tlabel")


for i in range(0,200):
    print("test",TEST_id_data[i],raw_TEST_x_data[i],final_y_data[i])
    print("predict",TEST_id_data[i],raw_TEST_x_data[i],y_predict[i])
    print("\n")
# Out:
# id	document	label
# test 6270596 굳 ㅋ 0
# predict 6270596 굳 ㅋ 0
#
#
# test 9274899 GDNTOPCLASSINTHECLUB 1
# predict 9274899 GDNTOPCLASSINTHECLUB 0
#
#
# test 8544678 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아 0
# predict 8544678 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아 0
#
#
# test 6825595 지루하지는 않은데 완전 막장임... 돈주고 보기에는.... 0
# predict 6825595 지루하지는 않은데 완전 막장임... 돈주고 보기에는.... 0
#
#
# test 6723715 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠?? 1
# predict 6723715 3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠?? 1
#
#
# test 7898805 음악이 주가 된, 최고의 음악영화 0
# predict 7898805 음악이 주가 된, 최고의 음악영화 0
#
#
# test 6315043 진정한 쓰레기 0
# predict 6315043 진정한 쓰레기 0
#
#
# test 6097171 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다 0
# predict 6097171 마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다 0
#
#
# test 8932678 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다 1
# predict 8932678 갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다 1
#
#
# test 6242223 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네.. 1
# predict 6242223 이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네.. 1
#
#
# test 7462111 괜찮네요오랜만포켓몬스터잼밌어요 1
# predict 7462111 괜찮네요오랜만포켓몬스터잼밌어요 0
#
#
# test 8425305 한국독립영화의 한계 그렇게 아버지가 된다와 비교됨 1
# predict 8425305 한국독립영화의 한계 그렇게 아버지가 된다와 비교됨 1
#
#
# test 6900881 청춘은 아름답다 그 아름다움은 이성을 흔들어 놓는다. 찰나의 아름다움을 잘 포착한 섬세하고 아름다운 수채화같은 퀴어영화이다. 0
# predict 6900881 청춘은 아름답다 그 아름다움은 이성을 흔들어 놓는다. 찰나의 아름다움을 잘 포착한 섬세하고 아름다운 수채화같은 퀴어영화이다. 1
#
#
# test 9629375 눈에 보이는 반전이었지만 영화의 흡인력은 사라지지 않았다. 1
# predict 9629375 눈에 보이는 반전이었지만 영화의 흡인력은 사라지지 않았다. 0
#
#
# test 9037756 "스토리, 연출, 연기, 비주얼 등 영화의 기본 조차 안된 영화에 무슨 평을 해. 이런 영화 찍고도 김문옥 감독은 ""내가 영화 경력이 몇OO인데 조무래기들이 내 영화를 평론해?"" 같은 마인드에 빠져있겠지?" 0
# predict 9037756 "스토리, 연출, 연기, 비주얼 등 영화의 기본 조차 안된 영화에 무슨 평을 해. 이런 영화 찍고도 김문옥 감독은 ""내가 영화 경력이 몇OO인데 조무래기들이 내 영화를 평론해?"" 같은 마인드에 빠져있겠지?" 0
#
#
# test 10268521 소위 ㅈ문가라는 평점은 뭐냐? 1
# predict 10268521 소위 ㅈ문가라는 평점은 뭐냐? 1
#
#
# test 2968565 최고!!!!!!!!!!!!!!!! 1
# predict 2968565 최고!!!!!!!!!!!!!!!! 0
#
#
# test 10107726 발연기 도저히 못보겠다 진짜 이렇게 연기를 못할거라곤 상상도 못했네 0
# predict 10107726 발연기 도저히 못보겠다 진짜 이렇게 연기를 못할거라곤 상상도 못했네 1
#
#
# test 6406912 나이스 1
# predict 6406912 나이스 0
#
#
# test 4174028 별 재미도없는거 우려먹어 .... 챔프에서 방송 몇번했더라 ? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 1
# predict 4174028 별 재미도없는거 우려먹어 .... 챔프에서 방송 몇번했더라 ? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 1
#
#
# test 9305768 '13일의 금요일', '나이트메어'시리즈와 함께 가장 많은 시리즈를 양산해냈던 헬레이저 시리즈의 첫편. 작가의 상상력이 돋보이는 작품이며, 갈고리로 사지찢는 고어씬은 지금보더라도 상당히 잔인하고 충격적이다. 1
# predict 9305768 '13일의 금요일', '나이트메어'시리즈와 함께 가장 많은 시리즈를 양산해냈던 헬레이저 시리즈의 첫편. 작가의 상상력이 돋보이는 작품이며, 갈고리로 사지찢는 고어씬은 지금보더라도 상당히 잔인하고 충격적이다. 0
#
#
# test 6829990 나름 교훈돋기는 하지만 어쩔수없이 저평점 받을수밖에 없는 저질섹스코미디 1
# predict 6829990 나름 교훈돋기는 하지만 어쩔수없이 저평점 받을수밖에 없는 저질섹스코미디 1
#
#
# test 9727606 꽤 재밌게 본 영화였다! 0
# predict 9727606 꽤 재밌게 본 영화였다! 1
#
#
# test 1385942 민주화 시대의 억눌린 영혼의 관음적인 욕구 분출.인상적이다. 1
# predict 1385942 민주화 시대의 억눌린 영혼의 관음적인 욕구 분출.인상적이다. 0
#
#
# test 9504429 일본 천황이 미국으로부터 받은 면죄부의 긴박한 과정을 루즈하고 지저분하게 늘어놓았다. 0
# predict 9504429 일본 천황이 미국으로부터 받은 면죄부의 긴박한 과정을 루즈하고 지저분하게 늘어놓았다. 0
#
#
# test 9952932 괜히 나올 때 어미 알 건드려서 긁어 부스름 만들었다는 분이 저 아래 보이던데, 영화 제대로 안 봤네. 알이 딱 까지면서 새끼가 나오려 했음. 그냥 가면 그 놈 한테 당했을 것임. 한 놈, 두 놈 막 나올 게 뻔했으니 작살낼 수 밖에 없었다. 0
# predict 9952932 괜히 나올 때 어미 알 건드려서 긁어 부스름 만들었다는 분이 저 아래 보이던데, 영화 제대로 안 봤네. 알이 딱 까지면서 새끼가 나오려 했음. 그냥 가면 그 놈 한테 당했을 것임. 한 놈, 두 놈 막 나올 게 뻔했으니 작살낼 수 밖에 없었다. 1
#
#
# test 9844172 50번은 봤네요어쩜 이렇게 잘만들었을까 1
# predict 9844172 50번은 봤네요어쩜 이렇게 잘만들었을까 1
#
#
# test 4022078 실화라서더욱아름답고찡하네요...많이울었어요벌써4년이란시간이흘렀네요 0
# predict 4022078 실화라서더욱아름답고찡하네요...많이울었어요벌써4년이란시간이흘렀네요 0
#
#
# test 9029890 이건뭐 노답이네 80~90년대 어린이 영화좀 보고 본받아라! 1
# predict 9029890 이건뭐 노답이네 80~90년대 어린이 영화좀 보고 본받아라! 1
#
#
# test 9541056 지금까지 본 영화중 마음이 가장 따뜻해지는 영화. 1
# predict 9541056 지금까지 본 영화중 마음이 가장 따뜻해지는 영화. 1
#
#
# test 1418173 너무너무 재밌다 1
# predict 1418173 너무너무 재밌다 0
#
#
# test 9567197 안보면 후회ㅠㅠ... 0
# predict 9567197 안보면 후회ㅠㅠ... 0
#
#
# test 9251651 평점1점도 주기싫어지는 영화 배우나 감독이라는 사람이나 영화판에서 안봐으면 한다 그리고 평점알바생들 너무 티난다 1
# predict 9251651 평점1점도 주기싫어지는 영화 배우나 감독이라는 사람이나 영화판에서 안봐으면 한다 그리고 평점알바생들 너무 티난다 1
#
#
# test 9573525 정말,진짜,표현할수 없는 영화... 0
# predict 9573525 정말,진짜,표현할수 없는 영화... 0
#
#
# test 6017377 엉성한 액션에, 시나리오는 왜그러지.. 막판에 대동단결?? 1
# predict 6017377 엉성한 액션에, 시나리오는 왜그러지.. 막판에 대동단결?? 0
#
#
# test 1018831 101, 102.. 103은 못나올것 같다. 1
# predict 1018831 101, 102.. 103은 못나올것 같다. 0
#
#
# test 6484287 ....재미가없어요 시간이 아깝고 0
# predict 6484287 ....재미가없어요 시간이 아깝고 1
#
#
# test 9523155 북괴는 우리의 주적일뿐이다. 1
# predict 9523155 북괴는 우리의 주적일뿐이다. 0
#
#
# test 9985937 ㅋㅋㅋ 난생처음 로그인하고 평점남기네요.. 개빡쳐서.. 알바들 속지마세요 이런 ㄱ ㅐ같은 시간낭비가. 아놔진짜평점 마이너스 별오만개 0
# predict 9985937 ㅋㅋㅋ 난생처음 로그인하고 평점남기네요.. 개빡쳐서.. 알바들 속지마세요 이런 ㄱ ㅐ같은 시간낭비가. 아놔진짜평점 마이너스 별오만개 0
#
#
# test 5017089 셰익스피어는 셰익스피어고 이영화는 이영화. 1
# predict 5017089 셰익스피어는 셰익스피어고 이영화는 이영화. 0
#
#
# test 9910232 EBS 한국영화특선 해서 봤다.Biff 개막작 선정되서 왤까 궁금 했었는데 봐도 이율 모르겠다... 1
# predict 9910232 EBS 한국영화특선 해서 봤다.Biff 개막작 선정되서 왤까 궁금 했었는데 봐도 이율 모르겠다... 0
#
#
# test 4585328 뭐야??라는 말 밖에는... 0
# predict 4585328 뭐야??라는 말 밖에는... 0
#
#
# test 362781 이게 영화야? 1
# predict 362781 이게 영화야? 0
#
#
# test 9417015 애니는 일본이 갑인듯. 1
# predict 9417015 애니는 일본이 갑인듯. 0
#
#
# test 8615279 롭 코헨의 몰락의 OO점 1
# predict 8615279 롭 코헨의 몰락의 OO점 1
#
#
# test 657926 감동적이다.... 0
# predict 657926 감동적이다.... 0
#
#
# test 7799381 은빛날개의 조종사 0
# predict 7799381 은빛날개의 조종사 1
#
#
# test 7789587 마음이1을보신분들은 이해하시겟지만 2는망장입니다 졸작이죠 솔직히말해선;; 그이유는 예를들면 엽기적인그녀는 긴시간을두고 코메디 멜로를 그렷습니다 하지만 이영화는 단시간 10분안에 모든것을 소화하려는 욕심 코믹하다 3분채안돼갑자기 생뚱맞게 슬픈음악이깔리고 0
# predict 7789587 마음이1을보신분들은 이해하시겟지만 2는망장입니다 졸작이죠 솔직히말해선;; 그이유는 예를들면 엽기적인그녀는 긴시간을두고 코메디 멜로를 그렷습니다 하지만 이영화는 단시간 10분안에 모든것을 소화하려는 욕심 코믹하다 3분채안돼갑자기 생뚱맞게 슬픈음악이깔리고 0
#
#
# test 9757343 이런스타일 액션영화 굿굿!! 0
# predict 9757343 이런스타일 액션영화 굿굿!! 1
#
#
# test 9886140 제임스 헷필드 50먹고 더 파워풀해졌어ㅋㅋㅋㅋ 1
# predict 9886140 제임스 헷필드 50먹고 더 파워풀해졌어ㅋㅋㅋㅋ 0
#
#
# test 5936280 돈만있으면 내가 이것보단 더잘만들겠따 ㅋ 1
# predict 5936280 돈만있으면 내가 이것보단 더잘만들겠따 ㅋ 1
#
#
# test 6342609 레이토와 다미앙의 시원한 액션은 어디갔나 ㅁㅊ 0
# predict 6342609 레이토와 다미앙의 시원한 액션은 어디갔나 ㅁㅊ 0
#
#
# test 9933994 내 참, 이딴 걸 드라마라고.... 그냥 이건 세계보건기구에서 발암물질로 올려야 한다. 1
# predict 9933994 내 참, 이딴 걸 드라마라고.... 그냥 이건 세계보건기구에서 발암물질로 올려야 한다. 1
#
#
# test 8183204 아 극장에서 아무 기대없이 들어갔다가 감탄하면서 보고 나왔는데. 2001년도 였구나 그 때가. 0
# predict 8183204 아 극장에서 아무 기대없이 들어갔다가 감탄하면서 보고 나왔는데. 2001년도 였구나 그 때가. 1
#
#
# test 2590934 아이디어가 아주 좋다 재밌다 1
# predict 2590934 아이디어가 아주 좋다 재밌다 1
#
#
# test 2077221 난 재밌던데 평점 왜케 낮지 ``; 1
# predict 2077221 난 재밌던데 평점 왜케 낮지 ``; 0
#
#
# test 7208743 역사얘기보다 영화배우, 감독들들에게 더 관심이 간다 0
# predict 7208743 역사얘기보다 영화배우, 감독들들에게 더 관심이 간다 0
#
#
# test 7926036 몇년만에 아메리칸조크보고 웃어보는거지. 하아이맛이야바로 1
# predict 7926036 몇년만에 아메리칸조크보고 웃어보는거지. 하아이맛이야바로 1
#
#
# test 5543759 재밌다! 내용도 신선하고 의미도있으며 연기도 좋고 영상도좋다~~ 0
# predict 5543759 재밌다! 내용도 신선하고 의미도있으며 연기도 좋고 영상도좋다~~ 1
#
#
# test 6335957 여름이면 한결같이 생각나는 드라마 1
# predict 6335957 여름이면 한결같이 생각나는 드라마 0
#
#
# test 9745015 콩콩~~~~ㅋㄲㅈㅁ 0
# predict 9745015 콩콩~~~~ㅋㄲㅈㅁ 0
#
#
# test 8582196 ...으...뭐 의도는 좋아봤자 전달이 돼야지; 0
# predict 8582196 ...으...뭐 의도는 좋아봤자 전달이 돼야지; 0
#
#
# test 5347773 아빠가 낚여서 본적 있다나 슈래기 영화 0
# predict 5347773 아빠가 낚여서 본적 있다나 슈래기 영화 0
#
#
# test 5494222 """결혼은 현실이에요 징징징"" 성현아 벗겨놓고 이 정도 얘기 밖에 못 하냐." 0
# predict 5494222 """결혼은 현실이에요 징징징"" 성현아 벗겨놓고 이 정도 얘기 밖에 못 하냐." 1
#
#
# test 250638 엠비씨 무비채널에서 봤는데 또 봐도 엄청 잼나네여 .. 1
# predict 250638 엠비씨 무비채널에서 봤는데 또 봐도 엄청 잼나네여 .. 0
#
#
# test 8724656 어우.. 이게 진짜 무서웠어요?? 진짜로? 시간 아까웠습니다. 1
# predict 8724656 어우.. 이게 진짜 무서웠어요?? 진짜로? 시간 아까웠습니다. 1
#
#
# test 10196806 몇번을 봐도 볼때마다 재밌다 0
# predict 10196806 몇번을 봐도 볼때마다 재밌다 1
#
#
# test 9868290 재미있게 잘봤습니다 후속편을 기다리게 만드네요 0
# predict 9868290 재미있게 잘봤습니다 후속편을 기다리게 만드네요 1
#
#
# test 9690650 결말 뻔히 알면서 보는데도 너무 슬프고 많이 울었음. 1
# predict 9690650 결말 뻔히 알면서 보는데도 너무 슬프고 많이 울었음. 1
#
#
# test 6386772 한번본적은업지만재미있을것같다 0
# predict 6386772 한번본적은업지만재미있을것같다 0
#
#
# test 10235375 성경에 보면 지나치게 의인도 되지 말고 지혜롭게 되지도 말라고 했다. 주인공의 지나친 착한남자 컴플렉스는 결국 모든걸 엉망으로 만들었다.직장에서 해고되고 부인에게 거부당하고,그 모든 터전을 잃을만큼 불륜으로 생긴 아이를 보러가는게 그리 중요했을까??? 0
# predict 10235375 성경에 보면 지나치게 의인도 되지 말고 지혜롭게 되지도 말라고 했다. 주인공의 지나친 착한남자 컴플렉스는 결국 모든걸 엉망으로 만들었다.직장에서 해고되고 부인에게 거부당하고,그 모든 터전을 잃을만큼 불륜으로 생긴 아이를 보러가는게 그리 중요했을까??? 0
#
#
# test 8518278 미친놈들 집합소네 연출력 빵점, 스토리 빵점. 구성빵점 1
# predict 8518278 미친놈들 집합소네 연출력 빵점, 스토리 빵점. 구성빵점 0
#
#
# test 3914112 하...작은 그림보고 기대했는데..수염..눈색깔도 뭐..이건 뭐 원작 비충실..ㄹㄹ 0
# predict 3914112 하...작은 그림보고 기대했는데..수염..눈색깔도 뭐..이건 뭐 원작 비충실..ㄹㄹ 1
#
#
# test 9270169 볼 거 없을때 봐도 재미 없는 영화! 1
# predict 9270169 볼 거 없을때 봐도 재미 없는 영화! 0
#
#
# test 8666222 관객모독 관객모독 관객모독 관객모독 0
# predict 8666222 관객모독 관객모독 관객모독 관객모독 0
#
#
# test 10107299 이런내용완전좋다ㅠㅜㅜㅜ 0
# predict 10107299 이런내용완전좋다ㅠㅜㅜㅜ 1
#
#
# test 8366483 쇼타군 넘 좋아 돈키호테 대박 재밌음 1
# predict 8366483 쇼타군 넘 좋아 돈키호테 대박 재밌음 1
#
#
# test 8912109 참 대단한것 같습니다천...재..? 0
# predict 8912109 참 대단한것 같습니다천...재..? 1
#
#
# test 2854944 볼만함 0
# predict 2854944 볼만함 0
#
#
# test 5840383 제시카 알바가 벗고 달려드는데 쌩까는게 말이 되냐? 1
# predict 5840383 제시카 알바가 벗고 달려드는데 쌩까는게 말이 되냐? 0
#
#
# test 8771808 솔직히 이건 C급 그 이하의 영화이긴 함 ㅎㅎ; 0
# predict 8771808 솔직히 이건 C급 그 이하의 영화이긴 함 ㅎㅎ; 1
#
#
# test 8365806 개성있는 몬스터들과 귀여운 여자아이가 만나 뿜어내는 매력에 퐁당 빠졌다 1
# predict 8365806 개성있는 몬스터들과 귀여운 여자아이가 만나 뿜어내는 매력에 퐁당 빠졌다 0
#
#
# test 10018785 제목이 찰지구나ㅋㅋㅋ 0
# predict 10018785 제목이 찰지구나ㅋㅋㅋ 1
#
#
# test 8069783 1956년 작품이라는게 믿기지가 않을정도로 디테일하다! 안소니 퀸의 명연기 또한 물론~ 0
# predict 8069783 1956년 작품이라는게 믿기지가 않을정도로 디테일하다! 안소니 퀸의 명연기 또한 물론~ 1
#
#
# test 2541728 아찔한 사랑 줄다리기??? 0
# predict 2541728 아찔한 사랑 줄다리기??? 1
#
#
# test 9648521 재미있었다! 또봐야징ㅎ 1
# predict 9648521 재미있었다! 또봐야징ㅎ 0
#
#
# test 9911421 중간에 화면이 좀 끊기는것 빼곤 넘 좋았어요~ 0
# predict 9911421 중간에 화면이 좀 끊기는것 빼곤 넘 좋았어요~ 0
#
#
# test 3608055 이 영화를 말하는데 긴 단어는 필요없다. 재수없는 졸작 이거면 충분하다. 1
# predict 3608055 이 영화를 말하는데 긴 단어는 필요없다. 재수없는 졸작 이거면 충분하다. 1
#
#
# test 9308174 최고최고! 바다까지! 4차원 고양이 로봇 도라에몽과 함께하는 진구와 친구들의 미지 탐험 이야기!우주꺼지 갔음 좋겠당~ 1
# predict 9308174 최고최고! 바다까지! 4차원 고양이 로봇 도라에몽과 함께하는 진구와 친구들의 미지 탐험 이야기!우주꺼지 갔음 좋겠당~ 0
#
#
# test 7530635 완전 잼없음.. 1
# predict 7530635 완전 잼없음.. 0
#
#
# test 9912932 로코 굉장히 즐겨보는데, 이 영화는 좀 별로였다. 뭔가 사랑도 개그도 억지스런 느낌.. 0
# predict 9912932 로코 굉장히 즐겨보는데, 이 영화는 좀 별로였다. 뭔가 사랑도 개그도 억지스런 느낌.. 1
# test 9992247 후속작 계획은 없나요..? ㅜ 1
# predict 9992247 후속작 계획은 없나요..? ㅜ 0
#
#
# test 7957461 엔딩때까지 음성 넣은 것은 오버의 극치다 1
# predict 7957461 엔딩때까지 음성 넣은 것은 오버의 극치다 1
#
#
# test 552155 단 두마디 '감동' 1
# predict 552155 단 두마디 '감동' 0
#
#
# test 4663025 뭘 만든 건가? 1
# predict 4663025 뭘 만든 건가? 1
#
#
# test 6753658 전기톱은못들고다니는데 엔진톱이겠죠 1
# predict 6753658 전기톱은못들고다니는데 엔진톱이겠죠 1
#
#
# test 9665771 완전 재밌엇는데 왜 평점이?? 1
# predict 9665771 완전 재밌엇는데 왜 평점이?? 1
#
#
# test 8757576 제임스 완이 내 목표임 ㄷ 0
# predict 8757576 제임스 완이 내 목표임 ㄷ 0
#
#
# test 9850643 1점고 아깝다. 개막장 영화의 원조라고나 할까.아내와 사별한 지 얼마나 지났다고 딴 여자들 만나고 다니다가 결국 맥 라이언한테 꽂힌 톰 행크스나약혼자 두고 톰 행크스랑 썸 타다가 결국엔 약혼자 버리고 톰행크스한테 쪼르르 달려가는 맥 라이언이나. 1
# predict 9850643 1점고 아깝다. 개막장 영화의 원조라고나 할까.아내와 사별한 지 얼마나 지났다고 딴 여자들 만나고 다니다가 결국 맥 라이언한테 꽂힌 톰 행크스나약혼자 두고 톰 행크스랑 썸 타다가 결국엔 약혼자 버리고 톰행크스한테 쪼르르 달려가는 맥 라이언이나. 1
#
#
# test 9985753 가끔 문득 생각나서 다시보는 영화..색감이 정말 예술이죠 강렬하고 화려하고..츠지야안나의 너무도 아름답던 리즈시절도 볼 수 있고.. 1
# predict 9985753 가끔 문득 생각나서 다시보는 영화..색감이 정말 예술이죠 강렬하고 화려하고..츠지야안나의 너무도 아름답던 리즈시절도 볼 수 있고.. 0
#
#
# test 1449086 걸작은 몇안되고 졸작들만 넘쳐난다. 1
# predict 1449086 걸작은 몇안되고 졸작들만 넘쳐난다. 1
#
#
# test 3775927 이렇게 지겨울수가 0
# predict 3775927 이렇게 지겨울수가 1
#
#
# test 7444391 ost... 정말 좋았어요. 영화 자체도.. 의문은 남지만 ㅎㅎ 1
# predict 7444391 ost... 정말 좋았어요. 영화 자체도.. 의문은 남지만 ㅎㅎ 0
#
#
# test 8730650 펑퍼짐한 건빵바지(카고)를 입고 오도바이탈때 입는 잠바 같은 것을 입은 주인공겸 감독이 앞차기 옆차기 뒷차기 앞돌려차기등의 기술을 구사해 악당을 소탕하는 영화 주먹질도 하지만 앞차기와 옆차기의 비중이 크다 0
# predict 8730650 펑퍼짐한 건빵바지(카고)를 입고 오도바이탈때 입는 잠바 같은 것을 입은 주인공겸 감독이 앞차기 옆차기 뒷차기 앞돌려차기등의 기술을 구사해 악당을 소탕하는 영화 주먹질도 하지만 앞차기와 옆차기의 비중이 크다 1
#
#
# test 8703366 솔직히 생각보다 재밌어서 놀랐다... 이거 개봉하고 낸린줄도 모르고...ㅠ ㅠ 이제서야 봤네... 정말 두 사람의 커플댄스는... 명장면이다... 생각할수록 아쉽다... 단순 sm상업영화라고 생각하기엔... 두 사람의 춤이 너무 인상적이다... 0
# predict 8703366 솔직히 생각보다 재밌어서 놀랐다... 이거 개봉하고 낸린줄도 모르고...ㅠ ㅠ 이제서야 봤네... 정말 두 사람의 커플댄스는... 명장면이다... 생각할수록 아쉽다... 단순 sm상업영화라고 생각하기엔... 두 사람의 춤이 너무 인상적이다... 0
#
#
# test 8974196 이거 평점보니까 알바고용하는데 제작비보다 많이들어갔겠어요 정말 재미라고는 찾아볼 수 없고 특히 마지막에 여자애가 경상도사람이 들으면 코웃음 칠만큼 어색한 사투리로 엄마한테 말할때는 그나마 잡히던 감정도 깨져버렸습니다 0
# predict 8974196 이거 평점보니까 알바고용하는데 제작비보다 많이들어갔겠어요 정말 재미라고는 찾아볼 수 없고 특히 마지막에 여자애가 경상도사람이 들으면 코웃음 칠만큼 어색한 사투리로 엄마한테 말할때는 그나마 잡히던 감정도 깨져버렸습니다 1
#
#
# test 5916807 TV시리즈중에는 단연 최고乃 0
# predict 5916807 TV시리즈중에는 단연 최고乃 1
#
#
# test 159788 글쌔....슬프지만 너무 짜여진듯한 1
# predict 159788 글쌔....슬프지만 너무 짜여진듯한 0
#
#
# test 1677284 여기서 땡칠이 얘낳지 안나? 1
# predict 1677284 여기서 땡칠이 얘낳지 안나? 1
#
#
# test 9224872 너무재밌음ㅠㅠ뭐랄까 굉장히 따뜻한 느낌? 1
# predict 9224872 너무재밌음ㅠㅠ뭐랄까 굉장히 따뜻한 느낌? 1
#
#
# test 8363292 견자단나오는 영화중에 제일 노잼 0
# predict 8363292 견자단나오는 영화중에 제일 노잼 1
#
#
# test 9341404 재밌기만한데;;왜이렇게욕을하셍휴ㅠㅠ 0
# predict 9341404 재밌기만한데;;왜이렇게욕을하셍휴ㅠㅠ 1
#
#
# test 8576972 실제 사실은 어땠는지 모르겠으나 의로운 협객으로서 김두한이 거지패에서 종로 최고의 주먹으로 평정하는 초기 모습을 잘 보여 줌. 배경음악이 영상과 잘 어울린다는 느낌. 참고로 황정민이 우미관 지배인으로 나와서 유명하기도 한 영화. 0
# predict 8576972 실제 사실은 어땠는지 모르겠으나 의로운 협객으로서 김두한이 거지패에서 종로 최고의 주먹으로 평정하는 초기 모습을 잘 보여 줌. 배경음악이 영상과 잘 어울린다는 느낌. 참고로 황정민이 우미관 지배인으로 나와서 유명하기도 한 영화. 1
#
#
# test 9701446 재밌는데? 자막읽기 힘들었지만 영어권사람들이 보면 더 몰입될듯 공간이 한정되있지만 상상만으로도 충분히재미나고 생각할게 많은영화 바이러스가 언어라는게 참신한듯 바이러수를 소문 괴담 선동 찌라시 언론플레이 등과 대입해서 생각해보면 재밌을듯 1
# predict 9701446 재밌는데? 자막읽기 힘들었지만 영어권사람들이 보면 더 몰입될듯 공간이 한정되있지만 상상만으로도 충분히재미나고 생각할게 많은영화 바이러스가 언어라는게 참신한듯 바이러수를 소문 괴담 선동 찌라시 언론플레이 등과 대입해서 생각해보면 재밌을듯 1
#
#
# test 3442231 괜찮아요~ 1
# predict 3442231 괜찮아요~ 0
#
#
# test 8142288 내가 극장가서 본 영화중 제일 쓰레기 같았다 0
# predict 8142288 내가 극장가서 본 영화중 제일 쓰레기 같았다 1
#
#
# test 6910486 . 1
# predict 6910486 . 1
#
#
# test 8609968 피는 물보다 진하다. 이 한마디로 모든게 표현되는 영화. 0
# predict 8609968 피는 물보다 진하다. 이 한마디로 모든게 표현되는 영화. 1
#
#
# test 7086093 이뿌고 따뜻한 애니였어요 0
# predict 7086093 이뿌고 따뜻한 애니였어요 1
#
#
# test 5419400 너무 좋았음 0
# predict 5419400 너무 좋았음 1
#
#
# test 4773462 어렷을때 보고 박준형에 배신감을ㅋㅋㅋㅋ 0
# predict 4773462 어렷을때 보고 박준형에 배신감을ㅋㅋㅋㅋ 1
#
#
# test 3545112 차인표 말투 적응안돼, 송선미 이쁘다 0
# predict 3545112 차인표 말투 적응안돼, 송선미 이쁘다 1
#
#
# test 361256 과소평가! 확실히 재밌고 유쾌함 1
# predict 361256 과소평가! 확실히 재밌고 유쾌함 0
#
#
# test 9501525 훌륭한 작가와 뛰어난 연출진이 만나, 훌륭하고 뛰어난 한 편의 드라마가 만들어졌다. 1
# predict 9501525 훌륭한 작가와 뛰어난 연출진이 만나, 훌륭하고 뛰어난 한 편의 드라마가 만들어졌다. 1
#
#
# test 2357338 신선한 소재로 식상한 영화를 만들었어..유치한건 둘째치고 재밋게라도 만들던가.. 0
# predict 2357338 신선한 소재로 식상한 영화를 만들었어..유치한건 둘째치고 재밋게라도 만들던가.. 0
#
#
# test 8606100 다시봐도 정말 최고군요 잭 바우어 형님이 여기 나왔었다니 처음 볼땐 못 느꼈던 또하나의 재미 1
# predict 8606100 다시봐도 정말 최고군요 잭 바우어 형님이 여기 나왔었다니 처음 볼땐 못 느꼈던 또하나의 재미 1
#
#
# test 9840982 이런 쓰레기영화좀 만들지마라 진짜 재미없다ㅡㅡ 0
# predict 9840982 이런 쓰레기영화좀 만들지마라 진짜 재미없다ㅡㅡ 0
#
#
# test 7299625 정말 가슴아픈영화....질리지도 않는영화....몇번을봐도...음악도 너무 좋아요...OST도 구해 들었다는... 1
# predict 7299625 정말 가슴아픈영화....질리지도 않는영화....몇번을봐도...음악도 너무 좋아요...OST도 구해 들었다는... 1
#
#
# test 5445466 영화도 못만들었지만 이건 탄생하지 말았어야할 그자체로 쓰레기임.. 0
# predict 5445466 영화도 못만들었지만 이건 탄생하지 말았어야할 그자체로 쓰레기임.. 0
#
#
# test 8824453 정말 재밋어요...다들 연기도 잘하고 볼만해요...~~~ 0
# predict 8824453 정말 재밋어요...다들 연기도 잘하고 볼만해요...~~~ 1
#
#
# test 9416662 신기록 갱신인가..간닷 0
# predict 9416662 신기록 갱신인가..간닷 0
#
#
# test 7497024 오시이 마모루는 영화를 통해 책을 넘어서려 한다. 1
# predict 7497024 오시이 마모루는 영화를 통해 책을 넘어서려 한다. 1
#
#
# test 9337303 데어데블보다 못한 졸작. CG는 훌륭하지만 악마 인형탈쓰고 나오는게 웃기고 인물 관계나 스토리가 너무 뻔함. 시간이 아까움. 짧은 러닝타임이 고마울 정도. 0
# predict 9337303 데어데블보다 못한 졸작. CG는 훌륭하지만 악마 인형탈쓰고 나오는게 웃기고 인물 관계나 스토리가 너무 뻔함. 시간이 아까움. 짧은 러닝타임이 고마울 정도. 1
#
#
# test 10060871 마트라는 폐쇄된 공간속에서 그안에 갇힌 사람들의 심리변화가 인상적이네요. 결말이 인상적입니다. 0
# predict 10060871 마트라는 폐쇄된 공간속에서 그안에 갇힌 사람들의 심리변화가 인상적이네요. 결말이 인상적입니다. 0
#
#
# test 8821342 차인표 연기는 너무 현실적이여서 마음에 와닿는다 왕초드라마를볼때도 난 연기를하는건지 진짜 실제로 그러는건지 몰랐다 이영화 내용이 쥐어짜는스토리지만 차인표라는 배우때문에 영화가살았다 너무 현실적인 연기력이다 대단하다 눈물한방울 흘리지않았지만 마음이아팠다 1
# predict 8821342 차인표 연기는 너무 현실적이여서 마음에 와닿는다 왕초드라마를볼때도 난 연기를하는건지 진짜 실제로 그러는건지 몰랐다 이영화 내용이 쥐어짜는스토리지만 차인표라는 배우때문에 영화가살았다 너무 현실적인 연기력이다 대단하다 눈물한방울 흘리지않았지만 마음이아팠다 1
#
#
# test 9232564 이게뭐야엉엉 본시리즈말고 그냥나왔다면 이정도는안줬겠지만 본이라는 이름을 달고왔으니 엉엉 1
# predict 9232564 이게뭐야엉엉 본시리즈말고 그냥나왔다면 이정도는안줬겠지만 본이라는 이름을 달고왔으니 엉엉 1
#
#
# test 9628757 스토리가 신선하다. 재미있다. 좋다. 1
# predict 9628757 스토리가 신선하다. 재미있다. 좋다. 1
#
#
# test 3830959 재밌었다.진저 너무 무서버~ㅠ 0
# predict 3830959 재밌었다.진저 너무 무서버~ㅠ 1
#
#
# test 7037790 아직까지 잊지 못하는 영화. 제목부터 마음에 잔잔하게 와 닿는다. 영화 장면중에 소낙비를 피해놀라 달려 가는 부분은 정말 ☆어느 멋진날~☆ 햇살 비춰진 행복한 빗속을 달리듯 느껴졌었다 0
# predict 7037790 아직까지 잊지 못하는 영화. 제목부터 마음에 잔잔하게 와 닿는다. 영화 장면중에 소낙비를 피해놀라 달려 가는 부분은 정말 ☆어느 멋진날~☆ 햇살 비춰진 행복한 빗속을 달리듯 느껴졌었다 0
#
#
# test 9815594 지루하지않고 가볍게 볼수있는 코믹 스릴러 영화네요저는 잔인하고 무거운 스릴러 영화보다 오히려 좋았습니다 0
# predict 9815594 지루하지않고 가볍게 볼수있는 코믹 스릴러 영화네요저는 잔인하고 무거운 스릴러 영화보다 오히려 좋았습니다 0
#
#
# test 525303 김민이 너무 어설픔 졸작 1
# predict 525303 김민이 너무 어설픔 졸작 1
#
#
# test 8172041 화면 어지럽고 엉성함과 지루함의 연속임. 0
# predict 8172041 화면 어지럽고 엉성함과 지루함의 연속임. 1
#
#
# test 9671580 영화 다보고 평점 읽는것이 이영화 최고의 재미 ㅋ 1
# predict 9671580 영화 다보고 평점 읽는것이 이영화 최고의 재미 ㅋ 0
#
#
# test 5502072 정말 재밌게 잘봤습니다! 0
# predict 5502072 정말 재밌게 잘봤습니다! 1
#
#
# test 118927 예수쟁이들 좀 제발 인터넷에서 안 봤으면... 0
# predict 118927 예수쟁이들 좀 제발 인터넷에서 안 봤으면... 1
#
#
# test 7942095 작가의 예리함과 필력에 박수를 보냅니다. 진보한 드라마란 바로 이런 것 시청률 의식하지마시고 앞으로도 좋은내용 부탁드립니다 0
# predict 7942095 작가의 예리함과 필력에 박수를 보냅니다. 진보한 드라마란 바로 이런 것 시청률 의식하지마시고 앞으로도 좋은내용 부탁드립니다 0
#
#
# test 3828346 작품성을 떠나서 보고 나면 너무너무 찝찝해 지는 영화.. 1
# predict 3828346 작품성을 떠나서 보고 나면 너무너무 찝찝해 지는 영화.. 0
#
#
# test 10068251 초중학생 수준의 단조로운 대사와 지루하고 재미 없는 영화. 0
# predict 10068251 초중학생 수준의 단조로운 대사와 지루하고 재미 없는 영화. 1
#
#
# test 8844388 2012년도에 참으로 억지스럽네 미국을 욕해라 뭐 이런건가? ㅋㅋ 1
# predict 8844388 2012년도에 참으로 억지스럽네 미국을 욕해라 뭐 이런건가? ㅋㅋ 1
#
#
# test 530245 1편이 오억만배 재밌는 영화 2편도 나름대로는 재밌지만... 1
# predict 530245 1편이 오억만배 재밌는 영화 2편도 나름대로는 재밌지만... 0
#
#
# test 8893839 다시 봐도 수작이다. 미국 국수주의라 뭐라는 시점도 있겠으나 전쟁물 중에 손가락안에 꼽을정도로 잘만들어 졌다. 스토리 라인은 뻔하나 그 뻔한걸 너무 잘 살렸다. 언제 봐도 다시봐도 재미 있다. 10년이 지난 영화가.. 0
# predict 8893839 다시 봐도 수작이다. 미국 국수주의라 뭐라는 시점도 있겠으나 전쟁물 중에 손가락안에 꼽을정도로 잘만들어 졌다. 스토리 라인은 뻔하나 그 뻔한걸 너무 잘 살렸다. 언제 봐도 다시봐도 재미 있다. 10년이 지난 영화가.. 1
#
#
# test 4409316 클럽과 사건의 연결이 전혀안된다. 섹스클럽얘기는 흥미거리일뿐 스토리연관이 없다. 0
# predict 4409316 클럽과 사건의 연결이 전혀안된다. 섹스클럽얘기는 흥미거리일뿐 스토리연관이 없다. 1
#
#
# test 1141313 다니엘,,미쉘페이퍼,,마틴스콜세지~~ 쵝오 1
# predict 1141313 다니엘,,미쉘페이퍼,,마틴스콜세지~~ 쵝오 1
#
#
# test 8878448 탕웨이..이제껏 관심없었는데 이번 영화를 계기로 너무좋다..ㅠㅠ 1
# predict 8878448 탕웨이..이제껏 관심없었는데 이번 영화를 계기로 너무좋다..ㅠㅠ 1
#
#
# test 9193758 간만에 참 유쾌하게 웃은듯... 1
# predict 9193758 간만에 참 유쾌하게 웃은듯... 1
#
#
# test 8445227 액션이 진짜 꽤 괜찮았다. ㅎ 0
# predict 8445227 액션이 진짜 꽤 괜찮았다. ㅎ 0
#
#
# test 8009802 무슨 말이 더 필요한가 .. 아마 이 영화보고 법무관 또는 법조인이 되고싶다 라고 생각을 품엇던 사람이 있을듯 0
# predict 8009802 무슨 말이 더 필요한가 .. 아마 이 영화보고 법무관 또는 법조인이 되고싶다 라고 생각을 품엇던 사람이 있을듯 1
#
#
# test 8377274 개노답이다진짜 돈아까움 0
# predict 8377274 개노답이다진짜 돈아까움 0
#
#
# test 9109485 죠스보다더재밌음bb 0
# predict 9109485 죠스보다더재밌음bb 0
#
#
# test 6284304 두말할필요없다 이건 보지마 시간이 남으면 집에서 발닦고 잠이나 자라 1
# predict 6284304 두말할필요없다 이건 보지마 시간이 남으면 집에서 발닦고 잠이나 자라 1
#
#
# test 7677681 굿 1
# predict 7677681 굿 0
#
#
# test 10266236 마지막 도서카드에 그려진 모습을 보고 우는 이츠키의 모습을 보고 저도 울었습니다... 지금 본지 3달은 지난거 같은데 아직도 그 모습을 떠올리면 먹먹해지네요 1
# predict 10266236 마지막 도서카드에 그려진 모습을 보고 우는 이츠키의 모습을 보고 저도 울었습니다... 지금 본지 3달은 지난거 같은데 아직도 그 모습을 떠올리면 먹먹해지네요 0
#
#
# test 5878577 완전한 삶은 없다 그저 하나씩 배워나갈뿐. 1
# predict 5878577 완전한 삶은 없다 그저 하나씩 배워나갈뿐. 1
#
#
# test 9663349 어라이즈 시리즈 중에 그나마 나은 2편. 4편보면 진짜 노잼이라 욕밖에 안나오는데 그래도 이건 조금이나마 볼만한편. 극장판 주제에 오프닝은 1부터 4까지 애프터이펙트만 처바르고 바뀌질 않는데 예산이 모자란건지 감독이 미친건지 모르겠다 1
# predict 9663349 어라이즈 시리즈 중에 그나마 나은 2편. 4편보면 진짜 노잼이라 욕밖에 안나오는데 그래도 이건 조금이나마 볼만한편. 극장판 주제에 오프닝은 1부터 4까지 애프터이펙트만 처바르고 바뀌질 않는데 예산이 모자란건지 감독이 미친건지 모르겠다 0
#
#
# test 2983134 이야~ 미키루크 나오는 홈보이 영화를 다 아는 분들이 계시네~ 이야 놀라울뿐..... 0
# predict 2983134 이야~ 미키루크 나오는 홈보이 영화를 다 아는 분들이 계시네~ 이야 놀라울뿐..... 1
#
#
# test 4875018 팬이긴한데 이건 안봤네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ몰라 나도 1
# predict 4875018 팬이긴한데 이건 안봤네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ몰라 나도 1
#
#
# test 10154172 케이블에서 우연히 보게 된 월광보합 때문에 깔깔 거리고 웃다가 선리기연 마지막 장면에서 일생소애가 흘러나오는데 눈물이...되돌릴 수 없는 시간이 가장 아프게 와닿았다. 1
# predict 10154172 케이블에서 우연히 보게 된 월광보합 때문에 깔깔 거리고 웃다가 선리기연 마지막 장면에서 일생소애가 흘러나오는데 눈물이...되돌릴 수 없는 시간이 가장 아프게 와닿았다. 0
#
#
# test 8764536 보고싶다 기대 만발 싸랑해 키르아 ♥ 1
# predict 8764536 보고싶다 기대 만발 싸랑해 키르아 ♥ 0
#
#
# test 9954697 심심할때 보면 딱 좋은 영화 0
# predict 9954697 심심할때 보면 딱 좋은 영화 0
#
#
# test 5356859 별로 재미 없는데.....왜 7점이지? 1
# predict 5356859 별로 재미 없는데.....왜 7점이지? 0
#
#
# test 36164 노인들의 섹스 외엔 보여줄 게 없는 영화. 영활까? 0
# predict 36164 노인들의 섹스 외엔 보여줄 게 없는 영화. 영활까? 1
#
#
# test 319737 멀 말하고자하는지 아직도 이해가....공포도 아니여서 실망;ㅁ; 0
# predict 319737 멀 말하고자하는지 아직도 이해가....공포도 아니여서 실망;ㅁ; 1
#
#
# test 142684 역시 영화를 볼 때도 도덕성을 버려 둘 수는 없네요 1
# predict 142684 역시 영화를 볼 때도 도덕성을 버려 둘 수는 없네요 0
#
#
# test 9233698 그리스의 아름다운 풍경을 감상하면서 달달한 로맨스를 즐길 수 있는 영화! 보는내내 흐뭇한 미소를 지으며 봤다ㅎㅎㅎ 0
# predict 9233698 그리스의 아름다운 풍경을 감상하면서 달달한 로맨스를 즐길 수 있는 영화! 보는내내 흐뭇한 미소를 지으며 봤다ㅎㅎㅎ 0
#
#
# test 6915908 OO어썸!! 0
# predict 6915908 OO어썸!! 1
#
#
# test 2988615 조쉬나와서 바꾸먼.. 이건 뭐병- _-정신줄을 놓은건가 드팔마 0
# predict 2988615 조쉬나와서 바꾸먼.. 이건 뭐병- _-정신줄을 놓은건가 드팔마 1
#
#
# test 6039126 종교인이 아님에도 그 인간적인 고뇌가 느껴진다. 숭고한 감동!! 0
# predict 6039126 종교인이 아님에도 그 인간적인 고뇌가 느껴진다. 숭고한 감동!! 0
#
#
# test 8641123 수고요! 수고 수고 ㅅㄱ 1
# predict 8641123 수고요! 수고 수고 ㅅㄱ 1
#
#
# test 8204802 한회 한회 보면서 총체적으로 발연기다. 중량급 연기자들도 모두 하향 평준화되는듯. 작가의 생각도 너무 어이업슴. 일일극 치고는 최악으로 평점 1점도 아깝다. 1
# predict 8204802 한회 한회 보면서 총체적으로 발연기다. 중량급 연기자들도 모두 하향 평준화되는듯. 작가의 생각도 너무 어이업슴. 일일극 치고는 최악으로 평점 1점도 아깝다. 1
#
#
# test 8524344 전작에 비해 훨씬 스토리도 고급스러웠고, 무엇보다 이번편에서도 역시 간지나는 액션신은 스타뎀 성님이 도맡아 하시는거보고 더욱 좋았다. 1
# predict 8524344 전작에 비해 훨씬 스토리도 고급스러웠고, 무엇보다 이번편에서도 역시 간지나는 액션신은 스타뎀 성님이 도맡아 하시는거보고 더욱 좋았다. 1
#
#
# test 505501 아! 희망이란,,, 미래란,,, 0
# predict 505501 아! 희망이란,,, 미래란,,, 0
# test 7164339 먼지낀 회색초콜릿같은 맛의 영화랄까요 1
# predict 7164339 먼지낀 회색초콜릿같은 맛의 영화랄까요 1
#
#
# test 4134743 아주 진짜 영화를 찍어라, 영화를 찍어...ㅉㅉ 0
# predict 4134743 아주 진짜 영화를 찍어라, 영화를 찍어...ㅉㅉ 1
#
#
# test 9644499 이게 뭐가 다들 재밌다는거지 ㅋㅋㅋ 마지막 반전이 가장 최악이었는데... 0
# predict 9644499 이게 뭐가 다들 재밌다는거지 ㅋㅋㅋ 마지막 반전이 가장 최악이었는데... 1
#
#
# test 8334994 b급 액션의 진수.. 깨알같은 까메오들과.. 잔웃음.. 거기다가 엠버 허드의 ㅎㄷㄷ한 몸매 어느영화에서나 빛을 발한다. 0
# predict 8334994 b급 액션의 진수.. 깨알같은 까메오들과.. 잔웃음.. 거기다가 엠버 허드의 ㅎㄷㄷ한 몸매 어느영화에서나 빛을 발한다. 0
#
#
# test 7349090 어릴때 감동적으로 본 영화라 잊지 못합니다. 라스트장면에서 이불 뒤집어쓰고 울었던 기억이...꼭 다시 보고 싶습니다. 파일 좀 보내주세요. dodadan@naver.com 0
# predict 7349090 어릴때 감동적으로 본 영화라 잊지 못합니다. 라스트장면에서 이불 뒤집어쓰고 울었던 기억이...꼭 다시 보고 싶습니다. 파일 좀 보내주세요. dodadan@naver.com 0
#
#
# test 1678402 두 주인공의 관계와 로맨스는 어색하고, 요술인지 마법인지.. 뭘하는건지 0
# predict 1678402 두 주인공의 관계와 로맨스는 어색하고, 요술인지 마법인지.. 뭘하는건지 0
#
#
# test 366896 왜 헤라클레스의 인물묘사를 저따위로 했을까? 0
# predict 366896 왜 헤라클레스의 인물묘사를 저따위로 했을까? 1
#
#
# test 3515745 뭐야이거 무서워 0
# predict 3515745 뭐야이거 무서워 1
#
#
# test 6085571 오다기리 죠의 배바지가 기억에 남네요 1
# predict 6085571 오다기리 죠의 배바지가 기억에 남네요 0
#
#
# test 1544464 카메라로 이렇게까지..아름답다 1
# predict 1544464 카메라로 이렇게까지..아름답다 1
#
#
# test 6006410 이게영화냐?첫장면부터 역겨웠다 분위기있는척앵글잡으면 괜찮은영화인거같지?허세덩어리 1
# predict 6006410 이게영화냐?첫장면부터 역겨웠다 분위기있는척앵글잡으면 괜찮은영화인거같지?허세덩어리 1
#
#
# test 6639436 지상최고의 드라마? 이정도면 될까 ? 0
# predict 6639436 지상최고의 드라마? 이정도면 될까 ? 1
#
#
# test 10247986 사랑이 무엇인지 알려주는 영화 1
# predict 10247986 사랑이 무엇인지 알려주는 영화 1
#
#
# test 8137671 미국 당시의 시대흐름과 개개인들의 인간승리응 보여준 영화.. 좌절하고 힘들때보면.. 용기를 주는 영화 1
# predict 8137671 미국 당시의 시대흐름과 개개인들의 인간승리응 보여준 영화.. 좌절하고 힘들때보면.. 용기를 주는 영화 0
#
#
# test 9610429 3점이 제일 적어서 3점 준다 1
# predict 9610429 3점이 제일 적어서 3점 준다 1
#
#
# test 7614088 재미따!시간가는지 몰랐어 ㅋㅋ 1
# predict 7614088 재미따!시간가는지 몰랐어 ㅋㅋ 0
#
#
# test 775509 기대안해서 그런가.. 조카랑 너무 재밌게 봤다.나니아,샤크보다 0
# predict 775509 기대안해서 그런가.. 조카랑 너무 재밌게 봤다.나니아,샤크보다 0
#
#
# test 9876090 소품은 잘 만들었는데 연기를 너무 못하네요... 몰입이 안됨-_-; 엑기스만 보고 끝냄.... 내가 본 영화중에 최악이다... 1
# predict 9876090 소품은 잘 만들었는데 연기를 너무 못하네요... 몰입이 안됨-_-; 엑기스만 보고 끝냄.... 내가 본 영화중에 최악이다... 0
#
#
# test 7415980 신날 것 없는 애니. 1
# predict 7415980 신날 것 없는 애니. 1

# %%
#1번
final_x_data=[]
final_y_data=[]
for i,sentence in enumerate(new_x_data):
    new_sent=''
    for j, word in enumerate(final_vocabulary):
        if word in sentence:
            new_sent += word + ' ' 
    final_x_data.append(new_sent)
    final_y_data.append(new_y_data[i])
# Out:
# [1 0 0 ... 0 0 0]
